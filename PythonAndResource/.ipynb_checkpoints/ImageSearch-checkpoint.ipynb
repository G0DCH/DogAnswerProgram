# %%
import ImageSearch

# %%
ImageSearch.tableList
# Out:
# []

# %%
ImageSearch.run()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 216/216 [00:00<00:00, 468.78it/s]

# %%
ImageSearch.tableList
# Out:
# [['고든 세터',
#                         고든 세터_1    고든 세터_2    고든 세터_3    고든 세터_4    고든 세터_5  \
#   Pet                 99.071220  95.186348  99.501282  81.650475  91.262993
#   Dog                 99.071220  93.546539  99.501282  72.450691  68.566818
#   Mammal              99.071220  99.529922  99.501282  82.147057  92.414368
#   Canine              99.071220  94.363144  99.501282  82.147057  92.414368
#   Animal              99.071220  99.529922  99.501282  82.147057  92.414368
#   Appenzeller         79.576019   0.000000   0.000000   0.000000   0.000000
#   Soccer              62.726326   0.000000   0.000000   0.000000   0.000000
#   Sports              62.726326   0.000000   0.000000   0.000000   0.000000
#   Football            62.726326   0.000000   0.000000   0.000000   0.000000
#   Sport               62.726326   0.000000   0.000000   0.000000   0.000000
#   Team Sport          62.726326   0.000000   0.000000   0.000000   0.000000
# ...
